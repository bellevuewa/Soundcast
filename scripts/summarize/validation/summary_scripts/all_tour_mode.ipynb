# %% [raw]
# ---
# title: "All Tours"
# date: today
# ---

# %%
import pandas as pd
import polars as pl
import numpy as np
import plotly.express as px
import toml
from pathlib import Path
import util
import sys

sys.path.append("../../notebook_styling")
import psrc_theme

# %%
config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['tour', 'parcel_geog'])

# %%
df_tour = data.tour.join(data.parcel_geog, left_on='tdpcl', right_on='ParcelID', how='left')

# %%
mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: walk to transit",
            7: "7: park-and-ride",
            8: "8: school bus",
            9: "9:tnc"}
pdpurp_cat = {1: "1: Work",
              2: "2: School",
              3: "3: Escort",
              4: "4: other home-based",
              5: "4: other home-based",
              6: "4: other home-based",
              7: "4: other home-based",
              8: "4: other home-based",
              9: "4: other home-based",
              10: "4: other home-based"}
df_tour = df_tour.with_columns(
    tmodetp_label=pl.col("tmodetp").replace_strict(mode_cat, default=None),
    pdpurp_label=pl.col("pdpurp").replace_strict(pdpurp_cat, default=None))

# %%
def plot_mode_choice(df: pl.DataFrame, grp: str, title_name: str):
    df_plot = (
        df.group_by(['source', grp, 'tmodetp_label'])
        .agg(
            toexpfac_sum=pl.col('toexpfac').sum(),
            sample_count=pl.col('toexpfac').count()
        )
        .with_columns(
            (pl.col('toexpfac_sum') / pl.col('toexpfac_sum').sum().over(['source', grp])).alias('percentage')
        )
    )

    fig = px.bar(
        df_plot.sort(by=[grp, 'source']).to_pandas(),
        x="tmodetp_label",
        y="percentage",
        color="source",
        facet_col=grp,
        facet_col_wrap=2,
        barmode="group",
        hover_data=['sample_count'],
        title=title_name
    )
    fig.update_layout(
        height=500,
        width=900,
        font=dict(size=11),
        xaxis=dict(dtick=1, categoryorder='category ascending')
    )
    fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
    fig.for_each_yaxis(lambda a: a.update(tickformat=".1%"))
    fig.show()

# %%
# plot mode choice by purpose
all_tour = df_tour.filter(pl.col('parent') == 0)
plot_mode_choice(all_tour,'pdpurp_label', "tour mode choice by purpose")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="f0264c27-833c-4e0c-b239-7499ba02a453" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0264c27-833c-4e0c-b239-7499ba02a453")) {                    Plotly.newPlot(                        "f0264c27-833c-4e0c-b239-7499ba02a453",                        [{"alignmentgroup":"True","customdata":[[22905],[10228],[71406],[47113],[244114],[35],[201503],[1001257]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=1: Work\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["2: bike","7: park-and-ride","1: walk","6: walk to transit","4: hov 2",null,"5: hov 3+","3: sov"],"xaxis":"x3","y":[0.014328511705214878,0.006398254430078051,0.04466892411362469,0.029472131498266253,0.152708592290191,2.189469153820217e-05,0.1260527436863529,0.626348947584734],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[84752],[31045],[36578],[90517],[12707],[147968],[5],[197916]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=2: School\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["4: hov 2","1: walk","6: walk to transit","3: sov","2: bike","8: school bus",null,"5: hov 3+"],"xaxis":"x4","y":[0.14090389168196207,0.05161366477801718,0.06081251828797914,0.1504884552975288,0.021125940999654192,0.24600324528502646,8.312717793206183e-06,0.32904397095203897],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[269335],[277368],[16],[52006],[21145],[1968]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=3: Escort\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["4: hov 2","5: hov 3+",null,"1: walk","3: sov","2: bike"],"xaxis":"x","y":[0.4331272775224415,0.4460454330549114,2.5730174096790484e-05,0.08363271462985536,0.034004033204789674,0.0031648114139052295],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[84],[1049131],[41557],[550656],[671109],[438626],[102133]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=4: other home-based\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[null,"3: sov","2: bike","1: walk","4: hov 2","5: hov 3+","6: walk to transit"],"xaxis":"x2","y":[2.9439637527967657e-05,0.36769090903993135,0.014564559723211332,0.19298944098333998,0.2352048297828196,0.15372607678978978,0.035794744043380004],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[254],[366],[241],[108],[1405],[136],[23],[15],[28]],"hovertemplate":"source=survey\u003cbr\u003epdpurp_label=1: Work\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orient ...

# %%
all_tour = df_tour.filter(pl.col('CountyName').is_in(["King", "Kitsap", "Pierce", "Snohomish"]))
plot_mode_choice(all_tour,'CountyName', "tour mode choice by destination county")
# Out:
# <div>                            <div id="b3f95cc0-ec9e-4f6d-a3e1-f9f6b88d46bd" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3f95cc0-ec9e-4f6d-a3e1-f9f6b88d46bd")) {                    Plotly.newPlot(                        "b3f95cc0-ec9e-4f6d-a3e1-f9f6b88d46bd",                        [{"alignmentgroup":"True","customdata":[[74699],[1298674],[591906],[49343],[163576],[9367],[471806],[692293]],"hovertemplate":"source=model\u003cbr\u003eCountyName=King\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["8: school bus","3: sov","5: hov 3+","2: bike","6: walk to transit","7: park-and-ride","1: walk","4: hov 2"],"xaxis":"x3","y":[0.022287138567589113,0.3874714171826293,0.17660063777276003,0.01472194110149466,0.048804414762338946,0.0027947312141073806,0.14076769031740652,0.20655202908167405],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[45673],[133324],[67234],[8088],[80387],[211],[1864],[3606]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Kitsap\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["1: walk","3: sov","5: hov 3+","8: school bus","4: hov 2","7: park-and-ride","6: walk to transit","2: bike"],"xaxis":"x4","y":[0.13417962495629973,0.39168358368562844,0.19752223204763988,0.023761189469633095,0.23616354326105285,0.0006198826629689148,0.005476119828313067,0.010593824088464014],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[245894],[14332],[11232],[367],[35616],[127891],[271805],[416242]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Pierce\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["5: hov 3+","2: bike","6: walk to transit","7: park-and-ride","8: school bus","1: walk","4: hov 2","3: sov"],"xaxis":"x","y":[0.21888783749740737,0.012757938327136256,0.0099984065929664,0.00032669295046462504,0.031704349111030206,0.11384492677894104,0.24195307193743162,0.3705267768046225],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[389607],[12043],[29565],[283],[12275],[217923],[241709],[112894]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Snohomish\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["3: sov","2: bike","8: school bus","7: park-and-ride","6: walk to transit","5: hov 3+","4: hov 2","1: walk"],"xaxis":"x2","y":[0.3833586375663068,0.011849859145782885,0.029090848264142738,0.00027846135832073043,0.01207813842186207,0.21442803741812203,0.2378325669906199,0.11108345083484289],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[87],[680],[804],[29],[303],[1271],[2484],[43],[1952],[55]],"hovertemplate":"source=survey\u003cbr\u003eCountyName=King\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{cus ...
