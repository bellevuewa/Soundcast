# %% [raw]
# ---
# title: "Intermediate Stop Generation"
# date: today
# ---

# %%
import polars as pl
import os
import pandas as pd
import numpy as np
import plotly.express as px
import toml
from pathlib import Path
import util
import sys

sys.path.append("../../notebook_styling")
import psrc_theme

# %%
# %store -r validation_data

# config = validation_data.config.copy()
# tour = validation_data.tour.copy()

config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['tour'])

tour = data.tour.to_pandas()

# %%
# df_person = person.copy()
df_tour = tour.copy()

# ptype_cat = {1: "1: full time worker",
#              2: "2: part time worker",
#              3: "3: non-worker age 65+",
#              4: "4: other non-working adult",
#              5: "5: university student",
#              6: "6: grade school student/child age 16+",
#              7: "7: child age 5-15",
#              8: "8: child age 0-4"}
pdpurp_cat = {1: "Work",
              2: "School",
              3: "Escort",
              4: "Personal Business",
              5: "Shop",
              6: "Meal",
              7: "Social",
              8: "Social",
              9: "Personal Business"}
# df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)
# df_person['pptyp_label'] = df_person['pptyp_label'].astype(pd.CategoricalDtype(["1: full time worker","2: part time worker","3: non-worker age 65+","4: other non-working adult","5: university student","6: grade school student/child age 16+","7: child age 5-15","8: child age 0-4"]))

df_tour['pdpurp_label'] = df_tour['pdpurp'].map(pdpurp_cat)
df_tour['pdpurp_label'] = df_tour['pdpurp_label'].astype(pd.CategoricalDtype(["Work","School","Shop","Meal","Escort","Personal Business"]))

df_tour['all_stops'] = df_tour['tripsh1'] + df_tour['tripsh2']
df_tour = df_tour.sort_values(['source'])
# df_tour = df_tour.merge(df_person, how='left', on=['pno','hhno','source'])

# %% [raw]
# :::{.panel-tabset}
# ### outbound: first half tour

# %%
df_plot = df_tour.groupby(['tripsh1','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot = df_plot.loc[df_plot['percentage'] > 0.001]

fig = px.bar(df_plot.sort_values(['source']), x="tripsh1", y="percentage", color="source",
             barmode="group",title="outbound: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="fa14ee03-6ad8-4126-aa5b-8ee41e355bad" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa14ee03-6ad8-4126-aa5b-8ee41e355bad")) {                    Plotly.newPlot(                        "fa14ee03-6ad8-4126-aa5b-8ee41e355bad",                        [{"alignmentgroup":"True","customdata":[[4532953.0],[977507.0],[235459.0],[56483.0],[19761.0]],"hovertemplate":"source=model\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x","y":[0.7772711754577982,0.1676143597580266,0.0403744520850134,0.009685211340903561,0.0033884436256501117],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4125668.5053439257],[619298.8889195758],[208088.26033411967],[61829.72114149175],[13742.604355308878],[16552.649244094813]],"hovertemplate":"source=survey\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2,3,4,5,6],"xaxis":"x","y":[0.8168472680944628,0.12261591179529849,0.04119970539472254,0.012241758817038,0.00272091875767448,0.00327728374135032],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor": ...

# %% [raw]
# ### inbound: second half tour

# %%
df_plot = df_tour.groupby(['tripsh2','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot = df_plot.loc[df_plot['percentage'] > 0.001]
# df_plot
fig = px.bar(df_plot.sort_values(['source']), x="tripsh2", y="percentage", color="source",
             barmode="group",title="inbound: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
# <div>                            <div id="7af72e50-1d1c-4d44-8545-f18bbde7a51c" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7af72e50-1d1c-4d44-8545-f18bbde7a51c")) {                    Plotly.newPlot(                        "7af72e50-1d1c-4d44-8545-f18bbde7a51c",                        [{"alignmentgroup":"True","customdata":[[3764760.0],[1469589.0],[445592.0],[102327.0],[32551.0]],"hovertemplate":"source=model\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x","y":[0.6455481516169483,0.2519922817355155,0.07640622296648371,0.017546139916092253,0.005581561077806629],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[8964.338556088549],[3554267.231897647],[953609.6606267445],[314846.65294045076],[125748.38004683006],[51608.26293540761],[21387.192412500604],[18625.14911936055]],"hovertemplate":"source=survey\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1,2,3,4,5,6,7],"xaxis":"x","y":[0.0017748627768639329,0.7037146767106136,0.18880660070058355,0.06233695896555153,0.024897109541280178,0.010217997043457128,0.00423448216252299,0.00368762108644824],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fd ...

# %% [raw]
# ### all stops

# %%
df_plot = df_tour.groupby(['all_stops','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot = df_plot.loc[df_plot['percentage'] > 0.001]
# df_plot
fig = px.bar(df_plot.sort_values(['source']), x="all_stops", y="percentage", color="source",
             barmode="group",title="all stops: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
# <div>                            <div id="e6355485-5d16-4cf2-a1c6-f5c9d5380eaa" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6355485-5d16-4cf2-a1c6-f5c9d5380eaa")) {                    Plotly.newPlot(                        "e6355485-5d16-4cf2-a1c6-f5c9d5380eaa",                        [{"alignmentgroup":"True","customdata":[[3140852.0],[7134.0],[15274.0],[39535.0],[278710.0],[109011.0],[709774.0],[1518618.0]],"hovertemplate":"source=model\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[2,9,8,7,5,6,4,3],"xaxis":"x","y":[0.5385658589398514,0.0012232759893420321,0.0026190520691351557,0.006779116377717584,0.047790755675570194,0.018692253837141053,0.12170584413502264,0.2603993462829574],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[238900.79554503007],[20385.909456919635],[88353.73309936484],[1062018.0282069487],[40563.82292679299],[18736.53857337795],[3036087.136189221],[528909.4638523225],[13046.958923220158]],"hovertemplate":"source=survey\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":[5,9,6,3,7,8,2,4,10],"xaxis":"x","y":[0.04730032525244871,0.0040362366549655,0.0174932875519884,0.21027053528034162,0.008031291873862324,0.003709675250783255,0.6011194257804691,0.1047195745507578,0.002583186879791409],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444 ...

# %% [raw]
# :::

# %% [markdown]
# ## number of stops by purpose

# %% [raw]
# :::{.panel-tabset}
# ### outbound

# %%
df_plot = df_tour.groupby(['tripsh1','pdpurp_label','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['pdpurp_label','source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot2 = df_plot.loc[(df_plot['percentage'] > 0.001) & (df_plot['tripsh1'] <= 10)]

fig = px.bar(df_plot2.sort_values(['source','pdpurp_label']),
             x="tripsh1", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2, 
             hover_data=['toexpfac'],
             title="outbound: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# <div>                            <div id="d7fec2ec-1e7c-420e-bbca-ea296a7af153" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7fec2ec-1e7c-420e-bbca-ea296a7af153")) {                    Plotly.newPlot(                        "d7fec2ec-1e7c-420e-bbca-ea296a7af153",                        [{"alignmentgroup":"True","customdata":[[1117353.0],[367999.0],[106865.0],[30493.0],[12958.0],[3547.0],[1932.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Work\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2,3,4,5,6,7],"xaxis":"x5","y":[0.6797961134274202,0.22389011346027368,0.06501652715070462,0.018551901580558985,0.007883630363718995,0.0021579901913961475,0.0011754262897596156],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[457682.0],[109122.0],[26695.0],[5954.0],[1655.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x6","y":[0.7608264526006593,0.18139866580002958,0.04437636208584694,0.009897616027688056,0.0027511848380624344],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[564250.0],[125455.0],[29796.0],[6390.0],[1666.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x3","y":[0.7751048812719276,0.17233634537876769,0.040930483017063986,0.008777882483522582,0.002288568422151584],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[305429.0],[54436.0],[12712.0],[2823.0],[787.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x4","y":[0.8113940359965465,0.14461313674702797,0.033770339377033935,0.007499501892807332,0.0020907219233579064],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[490020.0],[103219.0],[22691.0],[4749.0],[1343.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x","y":[0.7873527389116337,0.16584988848969415,0.036459371043312275,0.007630582745788638,0.0021579011639490716],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[331723.0],[54558.0],[8598.0],[1170.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Personal Business\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgro ...

# %% [markdown]
# - outliers

# %%
df_plot.loc[(df_plot['percentage'] > 0.001) & (df_plot['tripsh1'] > 10)]
# Out:
# Empty DataFrame
# Columns: [tripsh1, pdpurp_label, source, toexpfac, percentage]
# Index: []

# %% [raw]
# ### inbound

# %%
df_plot = df_tour.groupby(['tripsh2','pdpurp_label','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['pdpurp_label','source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot2 = df_plot.loc[df_plot['percentage'] > 0.001]

fig = px.bar(df_plot2.sort_values(['source','pdpurp_label']),
             x="tripsh2", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2,
             hover_data=['toexpfac'],
             title="inbound: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# <div>                            <div id="5129336f-8b00-4387-8596-4f977e116cb2" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5129336f-8b00-4387-8596-4f977e116cb2")) {                    Plotly.newPlot(                        "5129336f-8b00-4387-8596-4f977e116cb2",                        [{"alignmentgroup":"True","customdata":[[717109.0],[567375.0],[244388.0],[72136.0],[27065.0],[4062.0],[3014.0],[2295.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Work\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2,3,4,5,6,7,8],"xaxis":"x5","y":[0.43628818386295454,0.3451902128117815,0.14868534166758435,0.04388744867396461,0.016466310834546583,0.0024713155222585706,0.0018337136839210566,0.0013962750181150713],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[362556.0],[165645.0],[57741.0],[11880.0],[2782.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x6","y":[0.6026940000897667,0.27535952416969905,0.09598559742269669,0.019748686330019166,0.004624650283679573],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[510250.0],[173775.0],[37969.0],[5078.0],[772.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x3","y":[0.700925592678779,0.23871307176434065,0.05215765571468997,0.006975600508814972,0.0010604890887761242],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[284984.0],[74415.0],[14592.0],[2047.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4],"xaxis":"x4","y":[0.7570804277080427,0.19768878262602113,0.0387646941621837,0.00543800225808594],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[426071.0],[154272.0],[35902.0],[5126.0],[813.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x","y":[0.6846009730639947,0.24788066147784898,0.05768649857639581,0.0082363375773663,0.0013063094909088573],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[294539.0],[85762.0],[14523.0],[1308.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Personal Business\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mode ...

# %% [raw]
# ### all stops

# %%
df_plot = df_tour.groupby(['all_stops','pdpurp_label','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['pdpurp_label','source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot2 = df_plot.loc[(df_plot['percentage'] > 0.001) & (df_plot['all_stops'] <= 10)]

fig = px.bar(df_plot2.sort_values(['source','pdpurp_label']),
             x="all_stops", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2,
             hover_data=['toexpfac'],
             title="all stops: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# <div>                            <div id="b7fefd7a-7b95-47aa-8c5e-6d3d2c21eb23" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7fefd7a-7b95-47aa-8c5e-6d3d2c21eb23")) {                    Plotly.newPlot(                        "b7fefd7a-7b95-47aa-8c5e-6d3d2c21eb23",                        [{"alignmentgroup":"True","customdata":[[544389.0],[497018.0],[313853.0],[155156.0],[72089.0],[29777.0],[12793.0],[6343.0],[3736.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Work\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[2,3,4,5,6,7,8,9,10],"xaxis":"x5","y":[0.3312055602774055,0.30238510542636887,0.19094775741196926,0.09439670880638867,0.043858853935031535,0.01811628811085511,0.007783244578102879,0.00385907295856379,0.002272977545829153],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[304344.0],[154546.0],[87402.0],[36408.0],[12927.0],[3966.0],[1068.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[2,3,4,5,6,7,8],"xaxis":"x6","y":[0.5059254370726728,0.2569091311076719,0.14529248170171172,0.0605227417427052,0.02148916398890217,0.006592869527344783,0.001775386952900713],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[412224.0],[198017.0],[82552.0],[25381.0],[7312.0],[1867.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[2,3,4,5,6,7],"xaxis":"x3","y":[0.5662682048337422,0.27201407758054635,0.11340090059151114,0.034865639329309334,0.010044425151724119,0.002564680218581637],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[240355.0],[88616.0],[32797.0],[10375.0],[3112.0],[849.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[2,3,4,5,6,7],"xaxis":"x4","y":[0.6385202895663147,0.23541475725576144,0.08712758185561532,0.027561931327621705,0.008267251112439396,0.0022554293684000797],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[351163.0],[169756.0],[70616.0],[21935.0],[6510.0],[1687.0]],"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[2,3,4,5,6,7],"xaxis":"x","y":[0.5642405409053223,0.2727599925445559,0.11346414638378827,0.03524464782667378,0.010460116587720369,0.0027106323630544183],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[251417.0],[104201.0],[32451.0], ...

# %% [markdown]
# - outliers

# %%
df_plot.loc[(df_plot['percentage'] > 0.001) & (df_plot['all_stops'] > 10)]
# Out:
#      all_stops       pdpurp_label  source     toexpfac  percentage
# 132         11               Work   model  2371.000000    0.001443
# 143         11  Personal Business  survey  1001.476382    0.002894
# 144         12               Work   model  1751.000000    0.001065

# %% [raw]
# :::
