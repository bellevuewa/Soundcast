# %% [raw]
# ---
# title: "Escort Trip Mode"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import plotly.express as px
import toml
import polars as pl
from pathlib import Path
import util
import sys

sys.path.append("../../notebook_styling")
import psrc_theme

# %%
# %store -r validation_data

# config = validation_data.config.copy()
# hh = validation_data.hh.copy()
# person = validation_data.person.copy()
# trip = validation_data.trip.copy()
# df_parcel = validation_data.land_use.copy()

config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['hh', 'person', 'trip'])

hh = data.hh.to_pandas()
person = data.person.to_pandas()
trip = data.trip.to_pandas()
# df_parcel = data.land_use.to_pandas()

# %%
df_trip = trip.copy()
df_hh = hh.copy()
df_person = person.copy()

# Add column for (potential) drivers adults (all hh members 16 and above)
df_hh['drivers'] = df_hh['hhsize']-df_hh['hh515']-df_hh['hhcu5']#-df_hh['hhhsc']
# auto_ownership with 4+
df_hh['auto_ownership_4+'] = df_hh['hhvehs'].apply(lambda x: "4+" if x>=4.0 else str(x))
# hhsize with 4+
df_hh['hhsize_4+'] = df_hh['hhsize'].apply(lambda x: "4+" if x>=4.0 else str(x))
# auto availability
df_hh['auto_count_driver'] = df_hh['hhvehs']-df_hh['drivers']
df_hh['auto_count_worker'] = df_hh['hhvehs']-df_hh['hhwkrs']
df_hh['auto_available_driver'] = np.where(df_hh['drivers']<=0, "no driver",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_driver']<0, "cars fewer than drivers", "enough cars")))

df_hh['auto_available_worker'] = np.where(df_hh['hhwkrs']<=0, "no worker",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_worker']<0, "cars fewer than workers", "enough cars")))


# add person type labels
ptype_cat = {1: "full time worker",
             2: "part time worker",
             3: "non-worker age 65+",
             4: "other non-working adult",
             5: "university student",
             6: "grade school student/child age 16+",
             7: "child age 5-15",
             8: "child age 0-4"}
df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)

mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: transit",
            8: "8: school bus",
            9: "9: tnc"}
df_trip['mode_label'] = df_trip['mode'].map(mode_cat)

# df_hh = df_hh.merge(df_parcel,how="left",left_on='hhno',right_on='parcelid')
df_person = df_person[['pno','hhno','source', 'pptyp_label']].merge(df_hh[['hhno','source', 'auto_ownership_4+', 'hhsize_4+', 'drivers', 'auto_count_driver', 'auto_available_driver', 'hhcu5', 'hh515', 'hhhsc']],
                          how='left', on=['hhno','source']) # get auto ownership from hh data

df_trip = df_trip.merge(df_person, how='left', on=['pno','hhno','source'])

# %%
es_trip = df_trip.loc[(df_trip['dpurp']==3)].copy()

# %%
df_plot = es_trip.groupby(['source','mode_label'])['trexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['trexpfac']. \
    apply(lambda x: x / float(x.sum()))

df_plot_ct = es_trip.groupby(['source','mode_label'])['trexpfac'].count().reset_index(). \
    rename(columns={'trexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','mode_label'])

fig = px.bar(df_plot.sort_values(by=['source']), x="mode_label", y="percentage", color="source",
             barmode="group",hover_data=['sample count'],title="escort trip mode")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1bf1f8c1-d6d3-44c8-991f-60cc371cbf99" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bf1f8c1-d6d3-44c8-991f-60cc371cbf99")) {                    Plotly.newPlot(                        "1bf1f8c1-d6d3-44c8-991f-60cc371cbf99",                        [{"alignmentgroup":"True","customdata":[[170483],[22125],[573240],[482495],[400924],[10375],[17368]],"hovertemplate":"source=model\u003cbr\u003emode_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"xaxis":"x","y":[0.10165890483658416,0.013193123475709745,0.3418226486425245,0.2877114626627152,0.23907072706781712,0.0061866059236379035,0.010356527391011384],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[173],[28],[471],[633],[472],[8],[3],[1]],"hovertemplate":"source=survey\u003cbr\u003emode_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"xaxis":"x","y":[0.06075525335667176,0.001778999120371202,0.25378233470021266,0.34453209571636983,0.3384610818257987,0.0005522958490732918,0.00013116951978584774,6.7699117167693625e-06],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.66666666666 ...

# %% [markdown]
# ### mode choice by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### person type

# %%
def plot_mode_choice(df: pd.DataFrame, grp_var: str, order_list: dict, title_name: str, n_nol: int, height=400, width=800):
    df_plot = df.groupby(['source',grp_var,'mode_label'])['trexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['trexpfac']. \
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df.groupby(['source',grp_var,'mode_label'])['trexpfac'].count().reset_index(). \
        rename(columns={'trexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',grp_var,'mode_label'])

    fig = px.bar(df_plot.sort_values(['source','mode_label']),
                 x="percentage", y="mode_label", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 hover_data=['sample count'],
                 category_orders=order_list,
                 title="escort trip mode choice by " + title_name)
    fig.update_layout(height=height, width=width)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
    fig.show()

# %%
plot_mode_choice(es_trip,"pptyp_label",
                 {"pptyp_label":["full time worker","part time worker","non-worker age 65+","other non-working adult",
                                 "university student","grade school student/child age 16+","child age 5-15","child age 0-4"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬ÃƒÂ¢Ã¢â€šÂ¬Ã…â€œsurvey only"]},
                 "person type",
                 2,1000)
# Out:
# <div>                            <div id="b43871f0-9721-4db7-9df3-7e629491ba20" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b43871f0-9721-4db7-9df3-7e629491ba20")) {                    Plotly.newPlot(                        "b43871f0-9721-4db7-9df3-7e629491ba20",                        [{"alignmentgroup":"True","customdata":[[68202],[8584],[377670],[192285],[133674],[6805],[1]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.08663640832752174,0.010904180655749784,0.4797509212787769,0.24425796567926922,0.1698049213626161,0.008644332404750382,1.270291315907477e-06],"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":[[18150],[2074],[84191],[44150],[31491],[587]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.10047441639033895,0.011481208793033774,0.46606289753823843,0.2444047098420642,0.17432726427262613,0.0032495031636985655],"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":[[10847],[1217],[35709],[35145],[16740]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=non-worker age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.10884224046238135,0.012211764233679184,0.3583154388006984,0.3526560838066186,0.16797447269662244],"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[23657],[1876],[61209],[57466],[50325]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=other non-working adult\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.12160918713020413,0.009643608025373587,0.31464584414983576,0.29540489274313353,0.25869646795145296],"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[2475],[378],[9389],[3653],[3146],[715],[8]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=university student\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.12522768670309653,0.01912568306010929,0.47505565674964584,0.18483100586925724,0.15917830398704716,0.03617688726978344,0.0004047763610605141],"xaxis":"x3","y":["1: walk","2: bike","3: sov", ...

# %% [raw]
# ### household size

# %%
plot_mode_choice(es_trip,"hhsize_4+",
                 {"hhsize_4+":["1","2","3","4+"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬ÃƒÂ¢Ã¢â€šÂ¬Ã…â€œsurvey only"]},
                 "household size",2,600)
# Out:
# <div>                            <div id="b20413b2-df31-44aa-93d8-152996d2a403" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b20413b2-df31-44aa-93d8-152996d2a403")) {                    Plotly.newPlot(                        "b20413b2-df31-44aa-93d8-152996d2a403",                        [{"alignmentgroup":"True","customdata":[[16752],[1366],[34659],[11804],[6370],[775]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.23355547500209128,0.01904469787803586,0.4832138973315116,0.1645707274907286,0.08881019435072358,0.01080500794690907],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[36581],[3771],[137592],[90827],[27120],[2435],[571]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.12238664155210657,0.01261638624676728,0.46033248911832503,0.3038739097414829,0.09073359719234385,0.008146619069445327,0.0019103570795290686],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[33548],[3886],[116670],[97055],[76317],[2074],[2439]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.10105154086430575,0.01170520710023525,0.35142730632641445,0.29234402344655996,0.22987809837072914,0.006247194937181654,0.007346628954573796],"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[83602],[13102],[284319],[282809],[291117],[5091],[14358]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08579861617121545,0.013446250915950156,0.29178939201435145,0.29023971724079894,0.29876600731939107,0.005224764418646179,0.014735251919646798],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[15],[1],[51],[46],[9],[1]],"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.05043422764001628,0.000884507400701303,0.3857631155332662,0.4530382428080277,0.10848065445020118,0.0013992521677873297],"xaxis": ...

# %% [raw]
# ### auto ownership

# %%
plot_mode_choice(es_trip.loc[es_trip['auto_ownership_4+']!="-1"],
                 "auto_ownership_4+",
                 {"auto_ownership_4+":["0","1","2","3","4+"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬ÃƒÂ¢Ã¢â€šÂ¬Ã…â€œsurvey only"]},
                 "auto ownership",2,800)
# Out:
# <div>                            <div id="0acc3e1a-f21f-409c-9799-4857904f64c0" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0acc3e1a-f21f-409c-9799-4857904f64c0")) {                    Plotly.newPlot(                        "0acc3e1a-f21f-409c-9799-4857904f64c0",                        [{"alignmentgroup":"True","customdata":[[27824],[3158],[2185],[3078],[1376],[25]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.7390957870690114,0.08388673431440259,0.05804069489454391,0.08176167454709664,0.03655102799766243,0.0006640811772831111],"xaxis":"x5","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[37263],[4816],[94839],[97951],[63025],[2285],[3811]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.12257969012138557,0.01584262640218428,0.31198065725846247,0.32221783611303,0.20732589887825256,0.007516694628112767,0.01253659659857232],"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[61445],[7939],[255080],[211383],[183077],[3839],[8009]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08408231295123514,0.010863853568554897,0.34905551936855816,0.2892598512258269,0.25052547169294936,0.005253348513626685,0.010959642679248795],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[27144],[3875],[131664],[105981],[95752],[1811],[3727]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.07337128399746995,0.010474275180157533,0.35589289479232555,0.2864707504176195,0.25882136698075975,0.004895203187423302,0.01007422544424442],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[16807],[2337],[91657],[64995],[55992],[1064],[1796]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.07162643619378814,0.009959599059016059,0.3906148784562408,0.276 ...

# %% [raw]
# ### Household Type

# %%
plot_mode_choice(es_trip,
                 "hhcu5",
                 {
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬ÃƒÂ¢Ã¢â€šÂ¬Ã…â€œsurvey only"]},
                 "HH with Children Under 5",2,800)
# Out:
# <div>                            <div id="b41f403f-648c-4095-b9e6-9ca8a3664ca0" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b41f403f-648c-4095-b9e6-9ca8a3664ca0")) {                    Plotly.newPlot(                        "b41f403f-648c-4095-b9e6-9ca8a3664ca0",                        [{"alignmentgroup":"True","customdata":[[127244],[15680],[441017],[339554],[250721],[8342],[13254]],"hovertemplate":"source=model\u003cbr\u003ehhcu5=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.10640803069378799,0.013112429044030333,0.3688012831448422,0.28395266145514514,0.20966590065996996,0.006976012951868688,0.011083682050355741],"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[33023],[4790],[103160],[107270],[107290],[1556],[3365]],"hovertemplate":"source=model\u003cbr\u003ehhcu5=1.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.09161501883735511,0.013288796906123944,0.2861946323247904,0.2975969194404834,0.2976524050225549,0.0043167782851626,0.00933544918352966],"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[9224],[1483],[26640],[32394],[38182],[426],[672]],"hovertemplate":"source=model\u003cbr\u003ehhcu5=2.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08460755267333817,0.01360288384806597,0.24435659184927674,0.2971354142779831,0.3502261032278185,0.003907504058851047,0.00616395006466644],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[875],[159],[2284],[3057],[4305],[47],[66]],"hovertemplate":"source=model\u003cbr\u003ehhcu5=3.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08107106457889372,0.014731770592050403,0.2116186417122209,0.28323913647734644,0.39886963772815714,0.004354674325952006,0.006115074585379412],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[101],[11],[113],[197],[358],[4],[7]],"hovertemplate":"source=model\u003cbr\u003ehhcu5=4.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.1276864728192162,0.01390644753476612,0.14285714285714285,0.24905183312262957,0.4525916561314791,0.00 ...

# %% [raw]
# ### Kids 5-15

# %%
plot_mode_choice(es_trip,
                 "hh515",
                 {
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬ÃƒÂ¢Ã¢â€šÂ¬Ã…â€œsurvey only"]},
                 "HH with Children 5-15",2,800)
# Out:
# <div>                            <div id="caf0c2f4-729d-4808-8f2e-d764b28d9805" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caf0c2f4-729d-4808-8f2e-d764b28d9805")) {                    Plotly.newPlot(                        "caf0c2f4-729d-4808-8f2e-d764b28d9805",                        [{"alignmentgroup":"True","customdata":[[88449],[9775],[316640],[224319],[122057],[5549],[433]],"hovertemplate":"source=model\u003cbr\u003ehh515=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.11528475460818381,0.01274077125004236,0.4127097502417814,0.2923782164745015,0.15908954644157752,0.007232587178157039,0.0005643738057563521],"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":[[40648],[5655],[139644],[132936],[126514],[2461],[5724]],"hovertemplate":"source=model\u003cbr\u003ehh515=1.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08961554911791032,0.012467425956056457,0.30786935989523395,0.2930804132439118,0.2789220030777235,0.005425700314386373,0.012619548394777571],"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":[[28687],[4504],[87109],[90827],[106190],[1800],[7157]],"hovertemplate":"source=model\u003cbr\u003ehh515=2.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08792303401435603,0.013804348492371443,0.2669811262926252,0.27837645659782884,0.32546264795846436,0.0055168355431324595,0.02193555110122167],"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[8522],[1449],[21108],[24452],[32364],[383],[2665]],"hovertemplate":"source=model\u003cbr\u003ehh515=3.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.09370704727136778,0.015933056969750285,0.23210142616803933,0.26887171085185224,0.3558712600200125,0.004211429136931924,0.029304069582045896],"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[2773],[483],[5795],[6676],[9397],[121],[902]],"hovertemplate":"source=model\u003cbr\u003ehh515=4.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.10605423184304126,0.018472482502772784,0.22163154472788466,0.2553256587753853 ...

# %% [raw]
# ### High School Students

# %%
plot_mode_choice(es_trip,
                 "hhhsc",
                 {
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬ÃƒÂ¢Ã¢â€šÂ¬Ã…â€œsurvey only"]},
                 "HH with Driving Age Students",2,800)
# Out:
# <div>                            <div id="9af232c4-219a-4996-a7e1-76553f70576a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9af232c4-219a-4996-a7e1-76553f70576a")) {                    Plotly.newPlot(                        "9af232c4-219a-4996-a7e1-76553f70576a",                        [{"alignmentgroup":"True","customdata":[[154179],[19422],[509279],[423453],[344496],[8960],[13896]],"hovertemplate":"source=model\u003cbr\u003ehhhsc=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.1046214082385313,0.0131792072254247,0.3455819934382178,0.2873429532091322,0.23376501762588342,0.006079996742858888,0.009429423519951685],"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[14144],[2322],[56940],[51754],[49063],[1230],[2893]],"hovertemplate":"source=model\u003cbr\u003ehhhsc=1.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.07930651654648829,0.013019635988471848,0.31926704271472306,0.29018873425812747,0.275100086349007,0.006896706402162089,0.016221277741020265],"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[2098],[366],[6855],[7082],[7148],[176],[565]],"hovertemplate":"source=model\u003cbr\u003ehhhsc=2.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08637299300123508,0.015067929188966652,0.28221490325236726,0.2915603128859613,0.2942774804446274,0.00724578015644298,0.02326060107039934],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[50],[13],[160],[201],[206],[4],[14]],"hovertemplate":"source=model\u003cbr\u003ehhhsc=3.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.07716049382716049,0.020061728395061727,0.24691358024691357,0.3101851851851852,0.31790123456790126,0.006172839506172839,0.021604938271604937],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[12],[2],[6],[5],[11],[5]],"hovertemplate":"source=model\u003cbr\u003ehhhsc=6.0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.2926829268292683,0.04878048780487805,0.14634146341463414,0.12195121951219512,0.2682926829268293,0.12195121951219512],"xaxis" ...

# %% [raw]
# ### auto availability

# %%
plot_mode_choice(es_trip.loc[es_trip['auto_available_driver'] != "no dirver"], "auto_available_driver",
                 {"auto_available_driver": ["no car", "cars fewer than drivers", "enough cars"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬ÃƒÂ¢Ã¢â€šÂ¬Ã…â€œsurvey only"]},
                 "auto availability (driver, showing only households with at least one driver)", 3, 500, 1000)
# Out:
# <div>                            <div id="2abac860-6281-4263-9623-e76e3eed8dcb" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2abac860-6281-4263-9623-e76e3eed8dcb")) {                    Plotly.newPlot(                        "2abac860-6281-4263-9623-e76e3eed8dcb",                        [{"alignmentgroup":"True","customdata":[[27824],[3158],[2185],[3078],[1376],[25]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.7390957870690114,0.08388673431440259,0.05804069489454391,0.08176167454709664,0.03655102799766243,0.0006640811772831111],"xaxis":"x","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[49151],[7688],[142813],[169585],[118547],[3232],[5791]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.09893379119054281,0.015474822214662837,0.28746173061168623,0.3413498602072837,0.238617813356092,0.006505544406580422,0.011656438013151988],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[93508],[11279],[430427],[310725],[279299],[5767],[11552]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08184099349091555,0.00987171755982415,0.37672256176278296,0.2719557973912899,0.24445082389762612,0.005047450586710335,0.010110655310851013],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[13],[2],[2],[1],[1]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.7714049158487708,0.07031100961299085,0.11154217368756165,0.0257629106390028,0.020978990211673848],"xaxis":"x","y":["1: walk","3: sov","4: hov 2","5: hov 3+","6: transit"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[73],[17],[116],[159],[110],[1],[2]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08015340732914529,0.005654383270652039,0.305517061112511,0.3799094140318684,0.22855280800 ...

# %% [raw]
# :::
