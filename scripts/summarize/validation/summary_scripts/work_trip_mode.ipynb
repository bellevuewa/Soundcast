# %% [raw]
# ---
# title: "Work Trip Mode"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine,text
import plotly.express as px
import toml
import polars as pl
from pathlib import Path
import util
import sys

sys.path.append("../../notebook_styling")
import psrc_theme

# %%
config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['hh', 'person', 'trip', 'parcel_geog'])

hh = data.hh.to_pandas()
person = data.person.to_pandas()
trip = data.trip.to_pandas()
parcel_geog = data.parcel_geog.to_pandas()

# %%
df_trip = trip.copy()
df_hh = hh.copy()
df_person = person.copy()

# Add column for (potential) drivers adults (all hh members 16 and above)
df_hh['drivers'] = df_hh['hhsize']-df_hh['hh515']-df_hh['hhcu5']#-df_hh['hhhsc']
# auto_ownership with 4+
df_hh['auto_ownership_4+'] = df_hh['hhvehs'].apply(lambda x: "4+" if x>=4.0 else str(x))
# hhsize with 4+
df_hh['hhsize_4+'] = df_hh['hhsize'].apply(lambda x: "4+" if x>=4.0 else str(x))
# auto availability
df_hh['auto_count_driver'] = df_hh['hhvehs']-df_hh['drivers']
df_hh['auto_count_worker'] = df_hh['hhvehs']-df_hh['hhwkrs']
df_hh['auto_available_driver'] = np.where(df_hh['drivers']<=0, "no driver",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_driver']<0, "cars fewer than drivers", "enough cars")))

df_hh['auto_available_worker'] = np.where(df_hh['hhwkrs']<=0, "no worker",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_worker']<0, "cars fewer than workers", "enough cars")))


# add person type labels
ptype_cat = {1: "full time worker",
             2: "part time worker",
             3: "non-worker age 65+",
             4: "other non-working adult",
             5: "university student",
             6: "grade school student/child age 16+",
             7: "child age 5-15",
             8: "child age 0-4"}
df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)

mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: transit",
            8: "8: school bus",
            9: "9: tnc"}
df_trip['mode_label'] = df_trip['mode'].map(mode_cat)

df_hh = df_hh.merge(parcel_geog, left_on='hhparcel', right_on='ParcelID', how='left')
df_person = df_person.merge(df_hh,
                          how='left', on=['hhno','source']) # get auto ownership from hh data

df_trip = df_trip.merge(df_person, how='left', on=['pno','hhno','source'])

# %%
wk_trip = df_trip.loc[(df_trip['dpurp']==1)].copy()

# %%
# Load ACS data
conn = create_engine('sqlite:///../../../../inputs/db/'+input_config['db_name'])
df_acs = pd.read_sql(text("SELECT * FROM acs_commute_mode_by_home_county"), con=conn.connect())
df_acs.rename(columns={'share':'percentage'}, inplace=True)
df_acs['source'] = 'ACS'
df_acs['trexpfac'] = None

mode_cat_acs = {'Walk': "1: walk",
                'Bike': "2: bike",
                'SOV': "3: sov",
                'HOV2': "4: hov 2",
                'HOV3+': "5: hov 3+",
                'Transit': "6: transit",
                'TNC': "9: tnc"}
df_acs['mode_label'] = df_acs['mode'].map(mode_cat_acs)

df_acs_region = df_acs.loc[df_acs['county']=="Region"][['source','mode_label','trexpfac','percentage']].copy()

# %%
df_plot = wk_trip.groupby(['source','mode_label'])['trexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['trexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot = pd.concat([df_plot, df_acs_region], 
                    ignore_index=True)

df_plot_ct = wk_trip.groupby(['source','mode_label'])['trexpfac'].count().reset_index(). \
    rename(columns={'trexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','mode_label'], how='left')

fig = px.bar(df_plot.sort_values(by=['source']), x="mode_label", y="percentage", 
             color="source", barmode="group",
             category_orders={'source': ['model','survey','ACS']},
             hover_data=['sample count'],
             title="work trip mode")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="521cc66b-16d5-46df-a09c-07454bf7d244" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("521cc66b-16d5-46df-a09c-07454bf7d244")) {                    Plotly.newPlot(                        "521cc66b-16d5-46df-a09c-07454bf7d244",                        [{"alignmentgroup":"True","customdata":[[199143.0],[45.0],[53341.0],[127843.0],[205790.0],[1584002.0],[31075.0]],"hovertemplate":"source=model\u003cbr\u003emode_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","8: school bus","6: transit","5: hov 3+","4: hov 2","3: sov","2: bike"],"xaxis":"x","y":[0.0904685951866199,2.044303231043971e-05,0.024232261921581438,0.05807774621474542,0.09348825820367529,0.7195956459066917,0.014117049534375868],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[159.0],[2550.0],[84.0],[354.0],[20.0],[642.0],[222.0]],"hovertemplate":"source=survey\u003cbr\u003emode_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["2: bike","3: sov","5: hov 3+","6: transit","9: tnc","1: walk","4: hov 2"],"xaxis":"x","y":[0.00992909574135537,0.7554825410500934,0.032192753622235754,0.030581371241743937,0.006241959519563164,0.08338346942657605,0.08218880939843241],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[null],[null],[null],[null],[null],[null],[null]],"hovertemplate":"source=ACS\u003cbr\u003emode_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ACS","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"ACS","offsetgroup":"ACS","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","9: tnc","3: sov","5: hov 3+","4: hov 2","2: bike","6: transit"],"xaxis":"x","y":[0.0444064956042807,0.0017706464245474,0.7600213909796364,0.0264921276690358,0.082322353515969,0.0102536944774427,0.0747332913290878],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outl ...

# %% [markdown]
# ### mode choice by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### home county

# %%
df_plot = wk_trip.groupby(['source','CountyName','mode_label'])['trexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source','CountyName'], group_keys=False)['trexpfac']. \
    apply(lambda x: x / float(x.sum()))

df_acs_county = df_acs.loc[df_acs['county']!="Region"][['source','county','mode_label','trexpfac','percentage']].copy()
df_acs_county.rename(columns={'county':'CountyName'}, inplace=True)
df_plot = pd.concat([df_plot, df_acs_county], 
                    ignore_index=True)

df_plot_ct = wk_trip.groupby(['source','CountyName','mode_label'])['trexpfac'].count().reset_index(). \
    rename(columns={'trexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, how='left', on=['source','CountyName','mode_label'])
df_plot = df_plot.loc[df_plot['CountyName']!="Outside Region"].copy()

fig = px.bar(df_plot.sort_values(['mode_label'], ascending=False),
             x="percentage", y="mode_label", color="source",barmode="group",
             facet_col='CountyName', facet_col_wrap=2, orientation='h',
             hover_data=['sample count'],
             category_orders={"source":["model","survey","ACS"]},
             title="work trip mode choice by home county")
fig.update_layout(width=700, height=550)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
fig.show()
# Out:
# <div>                            <div id="b0860105-869f-499b-b57b-e6b1d9edd8e0" class="plotly-graph-div" style="height:550px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0860105-869f-499b-b57b-e6b1d9edd8e0")) {                    Plotly.newPlot(                        "b0860105-869f-499b-b57b-e6b1d9edd8e0",                        [{"alignmentgroup":"True","customdata":[[19.0],[38306.0],[70686.0],[115176.0],[879725.0],[22164.0],[148982.0]],"hovertemplate":"source=model\u003cbr\u003eCountyName=King\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[1.4901282922031782e-05,0.03004255492691313,0.055437478138249396,0.09033000851725961,0.6899490062412847,0.017382738667574338,0.11684331222579679],"xaxis":"x3","y":["8: school bus","6: transit","5: hov 3+","4: hov 2","3: sov","2: bike","1: walk"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[9.0],[5956.0],[6720.0],[11040.0],[84770.0],[1141.0],[8877.0]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Kitsap\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[7.594103600448896e-05,0.05025609004919292,0.05670264021668509,0.09315433749883979,0.7152801802333921,0.009627635786791322,0.07490317517909428],"xaxis":"x4","y":["8: school bus","6: transit","5: hov 3+","4: hov 2","3: sov","2: bike","1: walk"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[4.0],[2864.0],[26325.0],[40853.0],[322227.0],[3887.0],[20459.0]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Snohomish\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[9.60109836565303e-06,0.00687438642980757,0.06318722861895401,0.09805841788300582,0.7734332807673198,0.009329867336823332,0.04910721786572384],"xaxis":"x","y":["8: school bus","6: transit","5: hov 3+","4: hov 2","3: sov","2: bike","1: walk"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[13.0],[6215.0],[24112.0],[38721.0],[297279.0],[3883.0],[20825.0]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Pierce\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[3.324400073648248e-05,0.01589318958286451,0.061659949673697347,0.099018534809026,0.7602110226877519,0.009929727296904728,0.053254331949019046],"xaxis":"x2","y":["8: school bus","6: transit","5: hov 3+","4: hov 2","3: sov","2: bike","1: walk"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[14.0],[231.0],[41.0],[81.0],[1052.0],[117.0],[307.0]],"hovertemplate":"source=survey\u003cbr\u003eCountyName=King\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textpos ...

# %% [raw]
# ### person type

# %%
def plot_mode_choice(df: pd.DataFrame, grp_var: str, order_list: dict, title_name: str, n_nol: int, height=400, width=800):
    df_plot = df.groupby(['source',grp_var,'mode_label'])['trexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['trexpfac']. \
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df.groupby(['source',grp_var,'mode_label'])['trexpfac'].count().reset_index(). \
        rename(columns={'trexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',grp_var,'mode_label'])

    fig = px.bar(df_plot.sort_values(['source','mode_label']),
                 x="percentage", y="mode_label", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 hover_data=['sample count'],
                 category_orders=order_list,
                 title="work trip mode choice by " + title_name)
    fig.update_layout(height=height, width=width)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
    fig.show()

# %%
plot_mode_choice(wk_trip,"pptyp_label",
                 {"pptyp_label":["full time worker","part time worker","non-worker age 65+","other non-working adult",
                                 "university student","grade school student/child age 16+","child age 5-15","child age 0-4"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherâ€“survey only"]},
                  "person type",2,1000)
# Out:
# <div>                            <div id="7a94b443-5007-4709-ae04-3e55aa35325b" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a94b443-5007-4709-ae04-3e55aa35325b")) {                    Plotly.newPlot(                        "7a94b443-5007-4709-ae04-3e55aa35325b",                        [{"alignmentgroup":"True","customdata":[[158949],[23856],[1280599],[168233],[103958],[47738],[1]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.08913024705411325,0.01337719126086308,0.7180926287504191,0.09433622641636395,0.05829418381525839,0.02676896195552824,5.607474539261855e-07],"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":[[30995],[4835],[237396],[32595],[20460],[3663]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.09394018378876415,0.014654001891230027,0.7195039158160172,0.09878949155008122,0.06201052299784206,0.011101883956065272],"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":[[6975],[1757],[47891],[3245],[2271],[1692],[1]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=university student\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.10927121193131971,0.0275253791201905,0.7502663241007645,0.05083657099887204,0.035577766637423236,0.02650708108785562,1.5666123574382754e-05],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[2224],[627],[18116],[1717],[1154],[248],[43]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=grade school student\u002fchild age 16+\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.0921712462182436,0.02598532885739152,0.7507977951842182,0.07115918604169257,0.047826267147415974,0.010278088607070331,0.0017820879439678396],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[290],[103],[1326],[103],[48],[208],[11]],"hovertemplate":"source=survey\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0773031413930 ...

# %% [raw]
# ### household size

# %%
plot_mode_choice(wk_trip,"hhsize_4+",
                 {"hhsize_4+":["1","2","3","4+"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherâ€“survey only"]},
                 "household size",2,600)
# Out:
# <div>                            <div id="8f685d08-ba90-4f17-8081-cbd56702807a" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f685d08-ba90-4f17-8081-cbd56702807a")) {                    Plotly.newPlot(                        "8f685d08-ba90-4f17-8081-cbd56702807a",                        [{"alignmentgroup":"True","customdata":[[48409],[3879],[209984],[6715],[3906],[9464]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.17144607712930793,0.013737927517291939,0.7436826428953417,0.023781949801138274,0.013833551142702323,0.033517851514217815],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[71453],[9824],[513152],[57562],[15298],[17377],[4]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.10436122511574919,0.014348518264273299,0.749488074546862,0.08407261892590591,0.02234361079059985,0.025380110126046126,5.842230563629194e-06],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[28840],[5026],[305539],[41069],[30920],[9233],[7]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.06856316893070936,0.011948629925303232,0.7263773256560335,0.09763594954283296,0.0735080854139228,0.021950198985341174,1.664154585696829e-05],"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[50441],[12346],[555327],[100444],[77719],[17267],[34]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.061998972440257726,0.015174943275260639,0.6825737667439385,0.1234595822404244,0.09552741101652208,0.021223533576374975,4.1790707221680034e-05],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[159],[41],[422],[11],[19],[99],[4]],"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.15697914548729688,0.021361670175238552,0.6767872441155065,0.011990689551189575,0.04172989481338759,0.08976252649086937, ...

# %% [raw]
# ### auto ownership

# %%
plot_mode_choice(wk_trip.loc[wk_trip['auto_available_driver']!="no dirver"],"auto_available_driver",
                 {"auto_available_driver":["no car", "cars fewer than drivers","enough cars"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: otherâ€“survey only"]},
                 "auto availability (driver, showing only households with at least one driver)",3,500,1000)
# Out:
# <div>                            <div id="92cece3d-308f-49c9-8b06-ac663652fc22" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92cece3d-308f-49c9-8b06-ac663652fc22")) {                    Plotly.newPlot(                        "92cece3d-308f-49c9-8b06-ac663652fc22",                        [{"alignmentgroup":"True","customdata":[[28875],[5952],[2339],[813],[11779]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.580308694079344,0.11961895574580972,0.04700751637927569,0.016339081152779454,0.2367257526427911],"xaxis":"x","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: transit"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[59763],[19133],[368474],[85784],[56352],[17183],[34]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.09850129301180276,0.031534983839412715,0.607318331429664,0.1413890688172362,0.09287928758263655,0.028320996566802314,5.6038752445514676e-05],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[110505],[5990],[1215528],[117667],[70678],[24379],[11]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.07153547675428773,0.0038776300236024026,0.7868727658312823,0.07617180166731617,0.04575344487615536,0.015781759990885304,7.120856470722275e-06],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[106],[35],[7],[2],[2],[94],[7]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.4794900130431114,0.07986141408683052,0.014540644689519761,0.0010733211084926072,0.004780922875876112,0.33075150994999686,0.08950217424617275],"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","9: tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[97],[56],[345],[61],[18],[81],[3]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08701112853314083,0.019074568484151753,0.7015770230300322,0 ...

# %% [raw]
# ### auto availability

# %%
plot_mode_choice(wk_trip.loc[wk_trip['auto_available_worker']!="no worker"],"auto_available_worker",
                 {"auto_available_worker":["no car", "cars fewer than workers","enough cars"],
                     "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                      "8: school bus","9: otherâ€“survey only"]},
                 "auto availability (worker)",3,400,1000)
# Out:
# <div>                            <div id="4d2c8d43-ce13-459a-8564-59b1240a322c" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d2c8d43-ce13-459a-8564-59b1240a322c")) {                    Plotly.newPlot(                        "4d2c8d43-ce13-459a-8564-59b1240a322c",                        [{"alignmentgroup":"True","customdata":[[105],[35],[7],[2],[2],[93],[7]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.4750956911422639,0.08064538226538286,0.014683384495251544,0.0010838574808327195,0.0048278553205574025,0.33328304730983666,0.09038078198587488],"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","9: tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[87],[51],[187],[44],[17],[63],[2]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=cars fewer than workers\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":[0.1573636031140696,0.029386574371926953,0.5606983295452609,0.11718765897262824,0.05660551868232783,0.07492559081538741,0.0038327244983988843],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","9: tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[156],[37],[1399],[90],[41],[90],[5]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":[0.05242461471804919,0.0048248164251101415,0.7984205307016291,0.08971080952235831,0.033924036346262475,0.015424649304113323,0.005270542982477252],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","9: tnc"],"yaxis":"y3","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6e ...

# %% [raw]
# :::
