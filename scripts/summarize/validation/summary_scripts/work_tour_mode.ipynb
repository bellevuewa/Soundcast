# %% [raw]
# ---
# title: "Work Tour Mode"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px
import toml
import polars as pl
from pathlib import Path
import util
import sys

sys.path.append("../../notebook_styling")
import psrc_theme

# %%
config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['hh', 'person', 'tour', 'land_use', 'parcel_geog'])

# %%
hh = data.hh.join(data.land_use, how="left",left_on='hhno',right_on='parcelid').\
    join(data.parcel_geog, how="left",left_on='hhparcel',right_on='ParcelID').\
        to_pandas()
person = data.person.to_pandas()
tour = data.tour.to_pandas()

# %%
df_tour = tour.copy()
df_hh = hh.copy()
df_person = person.copy()

# Add column for (potential) drivers adults (all hh members 16 and above)
df_hh['drivers'] = df_hh['hhsize']-df_hh['hh515']-df_hh['hhcu5']#-df_hh['hhhsc']
# auto_ownership with 4+
df_hh['auto_ownership_4+'] = df_hh['hhvehs'].apply(lambda x: "4+" if x>=4.0 else str(x))
# hhsize with 4+
df_hh['hhsize_4+'] = df_hh['hhsize'].apply(lambda x: "4+" if x>=4.0 else str(x))
# auto availability
df_hh['auto_count_driver'] = df_hh['hhvehs']-df_hh['drivers']
df_hh['auto_count_worker'] = df_hh['hhvehs']-df_hh['hhwkrs']
df_hh['auto_available_driver'] = np.where(df_hh['drivers']<=0, "no driver",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_driver']<0, "cars fewer than drivers", "enough cars")))

df_hh['auto_available_worker'] = np.where(df_hh['hhwkrs']<=0, "no worker",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_worker']<0, "cars fewer than workers", "enough cars")))


# add person type labels
ptype_cat = {1: "full time worker",
             2: "part time worker",
             3: "non-worker age 65+",
             4: "other non-working adult",
             5: "university student",
             6: "grade school student/child age 16+",
             7: "child age 5-15",
             8: "child age 0-4"}
df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)

mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: walk to transit",
            7: "7: park-and-ride",
            8: "8: school bus",
            9: "9:tnc"}
df_tour['tmodetp_label'] = df_tour['tmodetp'].map(mode_cat)

df_person = df_person.merge(df_hh,  how='left', on=['hhno','source']) # get auto ownership from hh data

df_tour = df_tour.merge(df_person, how='left', on=['pno','hhno','source'])

# %%
wk_tour = df_tour.loc[(df_tour['parent']==0) & (df_tour['pdpurp']==1)].copy()

# %%
df_plot = wk_tour.groupby(['source','tmodetp_label'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))

df_plot_ct = wk_tour.groupby(['source','tmodetp_label'])['toexpfac'].count().reset_index(). \
    rename(columns={'toexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','tmodetp_label'])

fig = px.bar(df_plot.sort_values(by=['source']), x="tmodetp_label", y="percentage", color="source",
             barmode="group",hover_data=['sample count'],title="work tour mode")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="5214c673-c008-4c8f-ab05-ca50c75cd67f" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5214c673-c008-4c8f-ab05-ca50c75cd67f")) {                    Plotly.newPlot(                        "5214c673-c008-4c8f-ab05-ca50c75cd67f",                        [{"alignmentgroup":"True","customdata":[[71406],[22905],[1001257],[244114],[201503],[47113],[10228]],"hovertemplate":"source=model\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"xaxis":"x","y":[0.04466990214735325,0.014328825430427782,0.6263626616020008,0.15271193587092108,0.12605550363272164,0.029472776795622966,0.006398394520952428],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[241],[136],[1405],[254],[108],[366],[28],[23]],"hovertemplate":"source=survey\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"xaxis":"x","y":[0.04015659994823398,0.012772770514318047,0.6287021665160167,0.1453961988537698,0.11865931800187873,0.037442516186434294,0.0070939109909566025,0.009776518988391889],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.55555555555555 ...

# %% [markdown]
# ### mode choice by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### home county

# %%
def plot_mode_choice(df: pd.DataFrame, grp_var: str, order_list: dict, title_name: str, n_nol: int, height=400, width=800):
    df_plot = df.groupby(['source',grp_var,'tmodetp_label'])['toexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['toexpfac']. \
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df.groupby(['source',grp_var,'tmodetp_label'])['toexpfac'].count().reset_index(). \
        rename(columns={'toexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',grp_var,'tmodetp_label'])

    fig = px.bar(df_plot.sort_values(['source','tmodetp_label']),
                 x="percentage", y="tmodetp_label", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 hover_data=['sample count'],
                 category_orders=order_list,
                 title="work tour mode choice by " + title_name)
    fig.update_layout(height=height, width=width)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
    fig.show()

# %%
incl_county = ["King", "Kitsap", "Pierce", "Snohomish"]
order_mode = ["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
              "7: park-and-ride","8: school bus","9:tnc"]

plot_mode_choice(wk_tour.loc[wk_tour["CountyName"].isin(incl_county)],"CountyName",
                 {"CountyName":["King", "Kitsap", "Pierce", "Snohomish"],
                  "tmodetp_label":order_mode},
                 "home county",
                 2,600)
# Out:
# <div>                            <div id="274a4552-fea8-462b-b003-10f5af1236bc" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("274a4552-fea8-462b-b003-10f5af1236bc")) {                    Plotly.newPlot(                        "274a4552-fea8-462b-b003-10f5af1236bc",                        [{"alignmentgroup":"True","customdata":[[60495],[16871],[560999],[135166],[110122],[33991],[6603]],"hovertemplate":"source=model\u003cbr\u003eCountyName=King\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0654532825099784,0.01825377848129342,0.606979519544018,0.14624445629793767,0.11914780356333318,0.0367769654648595,0.007144194138579838],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[1874],[715],[53945],[12780],[10381],[6217],[859]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Kitsap\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.021597077364557283,0.008240080211130447,0.6216938839013034,0.1472842309066393,0.11963674499544778,0.07164836177985733,0.00989962084106441],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[4719],[2685],[184781],[46680],[38993],[5089],[1764]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Pierce\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.016574702066305833,0.009430615606702938,0.6490125074198047,0.16395573054781867,0.13695642247752984,0.017874265483244414,0.006195756398593662],"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4318],[2634],[201531],[49488],[42007],[1816],[1002]],"hovertemplate":"source=model\u003cbr\u003eCountyName=Snohomish\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.014260426161508077,0.008698926009590616,0.6655669163397139,0.1634367693100305,0.13873036631923805,0.005997437218457311,0.0033091586414615783],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[140],[100],[650],[110],[61],[241],[16],[16]],"hovertemplate":"source=survey\u003cbr\u003eCountyName=King\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition ...

# %% [raw]
# ### person type

# %%
plot_mode_choice(wk_tour,"pptyp_label",
                 {"pptyp_label":["full time worker","part time worker","non-worker age 65+","other non-working adult",
                                 "university student","grade school student/child age 16+","child age 5-15","child age 0-4"],
                  "tmodetp_label":order_mode},
                 "person type",2,1000)
# Out:
# <div>                            <div id="9abd60e9-3957-419b-8462-fd7fde3422a9" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9abd60e9-3957-419b-8462-fd7fde3422a9")) {                    Plotly.newPlot(                        "9abd60e9-3957-419b-8462-fd7fde3422a9",                        [{"alignmentgroup":"True","customdata":[[55811],[17480],[805651],[201631],[165832],[42017],[9357]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.04300501086856853,0.013469165397190123,0.6207921379526098,0.15536620641881244,0.12778138650725585,0.032376082522525024,0.0072100103330382135],"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":[[12473],[3621],[148953],[37981],[31375],[3394],[687]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.0523012025964006,0.015183408530551315,0.6245827812347998,0.15926016001073448,0.13156018852417772,0.01423156270441623,0.0028806963989198436],"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":[[2572],[1354],[33070],[3126],[3021],[1502],[157]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=university student\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.05740815142181153,0.030221865095308244,0.7381366903263247,0.06977367081826705,0.06743002544529263,0.033525289049596,0.003504307843399848],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[550],[450],[13583],[1376],[1275],[200],[27]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=grade school student\u002fchild age 16+\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.03149876868449688,0.025771719832770174,0.7779050455300384,0.07880419219975947,0.07301987285951549,0.01145409770345341,0.0015463031899662105],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[126],[93],[836],[148],[74],[214],[16],[13]],"hovertemplate":"source=survey\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"surv ...

# %% [raw]
# ### household size

# %%
plot_mode_choice(wk_tour,"hhsize_4+",
                 {"hhsize_4+":["1","2","3","4+"],
                  "tmodetp_label":order_mode},
                 "household size",2,600)
# Out:
# <div>                            <div id="d9f4e355-dc08-4e97-83a1-4922a15930ea" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9f4e355-dc08-4e97-83a1-4922a15930ea")) {                    Plotly.newPlot(                        "d9f4e355-dc08-4e97-83a1-4922a15930ea",                        [{"alignmentgroup":"True","customdata":[[26872],[3049],[153460],[6208],[6000],[8167],[1859]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.1306908542664689,0.014828684677674293,0.7463463268730394,0.030192349779928507,0.029180750431631933,0.03971986479585633,0.009041169175400628],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[28809],[7461],[341893],[72316],[25233],[15540],[3127]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.05827310626058146,0.015091660446742277,0.691560523404109,0.14627643973550655,0.0510397893114392,0.031433373990400075,0.0063251068512214315],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[7089],[3552],[190995],[46489],[47836],[8117],[1880]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.023169846841723372,0.011609436589335791,0.6242523483615399,0.15194569189235124,0.15634825695030036,0.026529785133907267,0.006144634230842142],"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[8636],[8843],[314909],[119101],[122434],[15289],[3362]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.01457370725006497,0.014923030710088528,0.5314256109785445,0.200989243537516,0.20661385750977937,0.025800997006281072,0.0056735530077256175],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[71],[31],[248],[12],[13],[102],[10],[6]],"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.1096861187 ...

# %% [raw]
# ### auto ownership

# %%
plot_mode_choice(wk_tour.loc[wk_tour['auto_ownership_4+']!="-1"],"auto_ownership_4+",
                 {"auto_ownership_4+":["0","1","2","3","4+"],
                  "tmodetp_label":order_mode},
                 "auto ownership",2,800)
# Out:
# <div>                            <div id="6156f165-2c0f-43a5-b416-1adc17e17d3c" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6156f165-2c0f-43a5-b416-1adc17e17d3c")) {                    Plotly.newPlot(                        "6156f165-2c0f-43a5-b416-1adc17e17d3c",                        [{"alignmentgroup":"True","customdata":[[17737],[5272],[242],[196],[10477],[2175]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.49134325050555416,0.1460428266710989,0.00670378680849885,0.005429513282916424,0.29022964625058867,0.06025097648134297],"xaxis":"x5","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[29699],[9088],[227242],[49783],[36183],[12415],[1184]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.08123492179849778,0.024858176009453108,0.6215692817715827,0.13617017784755767,0.09897044262214369,0.0339584347664349,0.0032385651843301584],"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[16426],[4456],[415822],[104238],[80833],[13851],[3610]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.02569629995807495,0.0069708214180678185,0.650498407473922,0.16306653567696439,0.12645251519000808,0.02166805373915111,0.005647366543811675],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[4549],[2422],[201163],[52749],[48078],[6326],[1880]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.014342601846976513,0.007636355610766568,0.6342494647929955,0.1663130149101262,0.1515857576607907,0.019945328486254875,0.0059274766920896565],"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[2995],[1667],[157030],[37102],[36213],[4044],[1379]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.0 ...

# %% [raw]
# ### auto availability

# %%
plot_mode_choice(wk_tour.loc[wk_tour['auto_available_worker']!="no worker"],"auto_available_worker",
                 {"auto_available_worker":["no car", "cars fewer than workers","enough cars"],
                     "tmodetp_label":order_mode},
                 "auto availability (worker)",3,400,1000)
# Out:
# <div>                            <div id="f7f028c2-26c7-484c-bc0d-bfb6c15a1d97" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7f028c2-26c7-484c-bc0d-bfb6c15a1d97")) {                    Plotly.newPlot(                        "f7f028c2-26c7-484c-bc0d-bfb6c15a1d97",                        [{"alignmentgroup":"True","customdata":[[61],[28],[5],[2],[94],[8],[9]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.33162075333188523,0.11708617032890141,0.015094540576180523,0.0012629595221177307,0.2943389024295359,0.13234066199678282,0.10825601181459636],"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[39],[42],[131],[50],[18],[71],[2],[2]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=cars fewer than workers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":[0.1060988398141951,0.04033813755687873,0.4538452075159754,0.1351450175146356,0.1680982368103493,0.08637305414920778,0.0020860812867314715,0.008015425352026631],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[55],[34],[873],[124],[67],[89],[10],[5]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":[0.01719763335097769,0.006044140892252372,0.6641545099626673,0.14778378563153557,0.1365315087923502,0.019203018363459116,0.002659252012953031,0.006426150993804644],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y3","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[ ...

# %%
plot_mode_choice(wk_tour.loc[wk_tour['auto_available_driver']!="no dirver"],"auto_available_driver",
                 {"auto_available_driver":["no car", "cars fewer than drivers","enough cars"],
                  "tmodetp_label":order_mode},
                 "auto availability (driver, showing only households with at least one driver)",3,500,1000)
# Out:
# <div>                            <div id="4ded6db9-be11-4a58-b623-23a23b5f732e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ded6db9-be11-4a58-b623-23a23b5f732e")) {                    Plotly.newPlot(                        "4ded6db9-be11-4a58-b623-23a23b5f732e",                        [{"alignmentgroup":"True","customdata":[[17737],[5272],[242],[196],[10477],[2175]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.49134325050555416,0.1460428266710989,0.00670378680849885,0.005429513282916424,0.29022964625058867,0.06025097648134297],"xaxis":"x","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[16432],[15320],[208107],[93837],[82819],[17599],[1217]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.03774599098157494,0.03519161281875171,0.4780431441822429,0.21555322272018304,0.19024374556372048,0.040426709790940686,0.002795573942586216],"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[37237],[2313],[793150],[150035],[118488],[19037],[6836]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":[0.03303800208677877,0.0020521765670359934,0.7037111301965405,0.1331164337376763,0.10512680375052347,0.016890309254934805,0.006065144406510182],"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[61],[28],[5],[2],[96],[8],[9]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":[0.32637825902519096,0.11523518972779413,0.014855915453241985,0.0012429937689561329,0.3054944897964292,0.13024852765328493,0.10654462457510275],"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[46],[47],[221],[74],[23],[87],[4],[3]],"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h" ...

# %% [raw]
# :::
