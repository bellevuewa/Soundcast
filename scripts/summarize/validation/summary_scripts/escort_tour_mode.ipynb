# %% [raw]
# ---
# title: "Escort Tour Mode"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import plotly.express as px
import toml
import polars as pl
from pathlib import Path
import util
import sys

sys.path.append("../../notebook_styling")
import psrc_theme

# %%
config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['hh', 'person', 'tour', 'land_use', 'parcel_geog'])

# %%
hh = data.hh.join(data.land_use, how="left",left_on='hhno',right_on='parcelid').\
    join(data.parcel_geog, how="left",left_on='hhparcel',right_on='ParcelID').\
        to_pandas()
person = data.person.to_pandas()
tour = data.tour.to_pandas()

# %%
df_tour = tour.copy()
df_hh = hh.copy()
df_person = person.copy()

# auto_ownership with 4+
df_hh['auto_ownership_4+'] = df_hh['hhvehs'].apply(lambda x: "4+" if x>=4.0 else str(x))
# hhsize with 4+
df_hh['hhsize_4+'] = df_hh['hhsize'].apply(lambda x: "4+" if x>=4.0 else str(x))
# Add column for (potential) drivers adults (all hh members 16 and above)
df_hh['drivers'] = df_hh['hhsize']-df_hh['hh515']-df_hh['hhcu5']#-df_hh['hhhsc']
# auto availability
df_hh['auto_count_driver'] = df_hh['hhvehs']-df_hh['drivers']
df_hh['auto_available_driver'] = np.where(df_hh['drivers']<=0, "no driver",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_driver']<0, "cars fewer than drivers", "enough cars")))

# add person type labels
ptype_cat = {1: "full time worker",
             2: "part time worker",
             3: "non-worker age 65+",
             4: "other non-working adult",
             5: "university student",
             6: "grade school student/child age 16+",
             7: "child age 5-15",
             8: "child age 0-4"}
df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)

mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: walk to transit",
            7: "7: park-and-ride",
            8: "8: school bus",
            9: "9: tnc"}
df_tour['tmodetp_label'] = df_tour['tmodetp'].map(mode_cat)

df_person = df_person[['pno','hhno','source', 'pptyp_label']].merge(df_hh[['hhno','source', 'auto_ownership_4+', 'hhsize_4+', 'drivers', 'auto_count_driver', 'auto_available_driver', 'CountyName', 'hhcu5', 'hh515', 'hhhsc']], how='left', on=['hhno','source']) # get auto ownership from hh data
df_tour = df_tour.merge(df_person, how='left', on=['pno','hhno','source'])

# %%
es_tour = df_tour.loc[(df_tour['parent']==0) & (df_tour['pdpurp']==3)].copy()

# %%
df_plot = es_tour.groupby(['source','tmodetp_label'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))

df_plot_ct = es_tour.groupby(['source','tmodetp_label'])['toexpfac'].count().reset_index(). \
    rename(columns={'toexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','tmodetp_label'])

fig = px.bar(df_plot.sort_values(by=['source']), x="tmodetp_label", y="percentage", color="source",
             barmode="group",hover_data=['sample count'],title="escort tour mode")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# ### mode choice by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### home county

# %%
def plot_mode_choice(df: pd.DataFrame, grp_var: str, order_list: dict, title_name: str, n_nol: int, height=400, width=800):
    df_plot = df.groupby(['source',grp_var,'tmodetp_label'])['toexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['toexpfac']. \
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df.groupby(['source',grp_var,'tmodetp_label'])['toexpfac'].count().reset_index(). \
        rename(columns={'toexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',grp_var,'tmodetp_label'])

    fig = px.bar(df_plot.sort_values(['source','tmodetp_label']),
                 x="percentage", y="tmodetp_label", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 category_orders=order_list,hover_data=['sample count'],
                 title="escort tour mode choice by " + title_name)
    fig.update_layout(height=height, width=width)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
    fig.show()

# %%
incl_county = ["King", "Kitsap", "Pierce", "Snohomish"]

plot_mode_choice(es_tour.loc[es_tour["CountyName"].isin(incl_county)],"CountyName",
                 {"CountyName":["King", "Kitsap", "Pierce", "Snohomish"],
                  "tmodetp_label":mode_cat.values()},
                 "home county",
                 2,600)
# Out:
# <div>                            <div id="62588167-7e91-4d82-81bd-ac38ebfc6207" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62588167-7e91-4d82-81bd-ac38ebfc6207")) {                    Plotly.newPlot(                        "62588167-7e91-4d82-81bd-ac38ebfc6207",                        [{"alignmentgroup":"True","customdata":[[31683],[1231],[10013],[136470],[132764]],"hovertemplate":"source=model\u003cbr\u003eCountyName=King\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.10149
# ...

# %% [raw]
# ### person type

# %%
plot_mode_choice(es_tour,"pptyp_label",
                 {"pptyp_label":["full time worker","part time worker","non-worker age 65+","other non-working adult",
                                 "university student","grade school student/child age 16+","child age 5-15","child age 0-4"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: otherÃƒÆ’Ã†â€™Ãƒâ€šÃ‚Â¢ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â€šÂ¬Ã…Â¡Ãƒâ€šÃ‚Â¬ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬Ãƒâ€¦Ã¢â‚¬Å“survey only"]},
                 "person type",
                 2,1000)
# Out:
# <div>                            <div id="e4bb16af-42ac-46e0-83d0-7eab4c16a438" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4bb16af-42ac-46e0-83d0-7eab4c16a438")) {                    Plotly.newPlot(                        "e4bb16af-42ac-46e0-83d0-7eab4c16a438",                        [{"alignmentgroup":"True","customdata":[[14889],[265],[5234],[65590],[61436]],"hovertemplate":"source=model\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x
# ...

# %% [raw]
# ### household size

# %%
plot_mode_choice(es_tour,"hhsize_4+",
                 {"hhsize_4+":["1","2","3","4+"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: otherÃƒÆ’Ã†â€™Ãƒâ€šÃ‚Â¢ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â€šÂ¬Ã…Â¡Ãƒâ€šÃ‚Â¬ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬Ãƒâ€¦Ã¢â‚¬Å“survey only"]},
                 "household size",2,600)
# Out:
# <div>                            <div id="c807eefe-84f4-4539-a4ab-6c8dc4a42e00" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c807eefe-84f4-4539-a4ab-6c8dc4a42e00")) {                    Plotly.newPlot(                        "c807eefe-84f4-4539-a4ab-6c8dc4a42e00",                        [{"alignmentgroup":"True","customdata":[[9568],[621],[1734],[16033],[7018]],"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.273574655458340
# ...

# %% [raw]
# ### auto ownership

# %%
plot_mode_choice(es_tour.loc[es_tour['auto_ownership_4+']!="-1"],
                 "auto_ownership_4+",
                 {"auto_ownership_4+":["0","1","2","3","4+"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: otherÃƒÆ’Ã†â€™Ãƒâ€šÃ‚Â¢ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â€šÂ¬Ã…Â¡Ãƒâ€šÃ‚Â¬ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬Ãƒâ€¦Ã¢â‚¬Å“survey only"]},
                 "auto ownership",2,800)
# Out:
# <div>                            <div id="329afbd3-6b82-43db-885c-b863e897971a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("329afbd3-6b82-43db-885c-b863e897971a")) {                    Plotly.newPlot(                        "329afbd3-6b82-43db-885c-b863e897971a",                        [{"alignmentgroup":"True","customdata":[[22056],[1963],[561],[757]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.870505584718001
# ...

# %% [raw]
# ### Household Type

# %%
plot_mode_choice(es_tour,
                 "hhcu5",
                 {
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: otherÃƒÆ’Ã†â€™Ãƒâ€šÃ‚Â¢ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â€šÂ¬Ã…Â¡Ãƒâ€šÃ‚Â¬ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬Ãƒâ€¦Ã¢â‚¬Å“survey only"]},
                 "HH with Children Under 5",2,800)
# Out:
# <div>                            <div id="5ef7baf3-f662-4b0c-98bd-cad9022f1b82" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ef7baf3-f662-4b0c-98bd-cad9022f1b82")) {                    Plotly.newPlot(                        "5ef7baf3-f662-4b0c-98bd-cad9022f1b82",                        [{"alignmentgroup":"True","customdata":[[40794],[1510],[16982],[197452],[157820]],"hovertemplate":"source=model\u003cbr\u003ehhcu5=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.09840360094
# ...

# %% [raw]
# ### Kids 5-15

# %%
plot_mode_choice(es_tour,
                 "hh515",
                 {
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: otherÃƒÆ’Ã†â€™Ãƒâ€šÃ‚Â¢ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â€šÂ¬Ã…Â¡Ãƒâ€šÃ‚Â¬ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬Ãƒâ€¦Ã¢â‚¬Å“survey only"]},
                 "HH with Children 5-15",2,800)
# Out:
# <div>                            <div id="57df18d6-3b7f-4efe-9473-f32bfca90a92" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57df18d6-3b7f-4efe-9473-f32bfca90a92")) {                    Plotly.newPlot(                        "57df18d6-3b7f-4efe-9473-f32bfca90a92",                        [{"alignmentgroup":"True","customdata":[[35114],[1299],[12949],[162165],[80511]],"hovertemplate":"source=model\u003cbr\u003ehh515=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.120237777275
# ...

# %% [raw]
# ### High School Students

# %%
plot_mode_choice(es_tour,
                 "hhhsc",
                 {
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: otherÃƒÆ’Ã†â€™Ãƒâ€šÃ‚Â¢ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â€šÂ¬Ã…Â¡Ãƒâ€šÃ‚Â¬ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬Ãƒâ€¦Ã¢â‚¬Å“survey only"]},
                 "HH with Driving Age Students",2,800)
# Out:
# <div>                            <div id="8183eec1-9a98-4fad-9052-e0f841db5a6f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8183eec1-9a98-4fad-9052-e0f841db5a6f")) {                    Plotly.newPlot(                        "8183eec1-9a98-4fad-9052-e0f841db5a6f",                        [{"alignmentgroup":"True","customdata":[[50155],[1835],[19259],[244872],[240758]],"hovertemplate":"source=model\u003cbr\u003ehhhsc=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.09006444847
# ...

# %% [raw]
# ### auto availability

# %%
plot_mode_choice(es_tour.loc[es_tour['auto_available_driver'] != "no dirver"], "auto_available_driver",
                 {"auto_available_driver": ["no car", "cars fewer than drivers", "enough cars"],
                  "tmodetp_label": ["1: walk", "2: bike", "3: sov", "4: hov 2", "5: hov 3+", "6: walk to transit",
                                    "7: park-and-ride", "8: school bus", "9: otherÃƒÆ’Ã†â€™Ãƒâ€šÃ‚Â¢ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â€šÂ¬Ã…Â¡Ãƒâ€šÃ‚Â¬ÃƒÆ’Ã‚Â¢ÃƒÂ¢Ã¢â‚¬Å¡Ã‚Â¬Ãƒâ€¦Ã¢â‚¬Å“survey only"]},
                 "auto availability (driver, showing only households with at least one driver)", 3, 500, 900)
# Out:
# <div>                            <div id="3289badc-a33c-4255-95fd-521a7d646d18" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3289badc-a33c-4255-95fd-521a7d646d18")) {                    Plotly.newPlot(                        "3289badc-a33c-4255-95fd-521a7d646d18",                        [{"alignmentgroup":"True","customdata":[[22056],[1963],[561],[757]],"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":[0.870505
# ...

# %% [raw]
# :::
