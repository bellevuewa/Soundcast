# %% [raw]
# ---
# title: "Household Transportation Costs"
# date: today
# ---

# %% [markdown]
# - Average Annual Household Transportation Costs: Out-of-pocket expenses including tolls, parking, and transit fares
#
#     - These costs do not include other vehicle operating and purchase costs.
#
#     - Costs are annualized using factor of 320

# %%
import pandas as pd
import polars as pl
from pathlib import Path
import util

pd.set_option('display.float_format', '${:0,.0f}'.format)

# %%
# person data
person = pd.read_csv(util.output_path / 'agg/dash/person_cost.csv')
# household data
hh = pd.read_csv(util.output_path / 'agg/dash/hh_geog.csv')

annual_factor = util.summary_config['weekday_to_annual']
# list of equity geographies
equity_geogs = util.summary_config['equity_geogs']
not_equity_geogs = ["NOT in " + item for item in equity_geogs]

# %%
df_person = person.copy()
df_person['is_rgc'] = "In RGC"
df_person.loc[df_person['hh_rgc'] == 'Not in RGC', 'is_rgc'] = "Not in RGC"
# included modes
# TODO: ask what this means
df_person = df_person[(df_person['mode'].isin(['SOV','HOV2','HOV3+']) & (df_person['dorp'] == 1)) 
                      | (~df_person['mode'].isin(['SOV','HOV2','HOV3+']))]

df_hh = hh.copy()
df_hh['is_rgc'] = "In RGC"
df_hh.loc[df_hh['hh_rgc'] == 'Not in RGC', 'is_rgc'] = "Not in RGC"

# %%
def annual_costs(geog, map=False):
    df = df_person.groupby(geog, as_index=False)['travcost_wt'].sum().set_index(geog)
    df['hhexpfac'] = df_hh.groupby(geog)['hhexpfac'].sum()

    if map:
        df.index = df.index.astype('int').map({
                                0: 'Below Regional Average', 
                                1: 'Above Regional Average', 
                                2: 'Higher Share of Equity Population'}
                                )

    df.loc['Region'] = [df_person['travcost_wt'].sum(), df_hh['hhexpfac'].sum()]
    df['Average Annual Costs'] = (df['travcost_wt'] / df['hhexpfac']) * annual_factor




    return df[['Average Annual Costs']]

# %% [raw]
# :::{.panel-tabset}
# ### County

# %%
df = annual_costs('hh_county')
df = df[df.index!='Outside Region']
df
# Out:
#            Average Annual Costs
# hh_county
# King                     $2,432
# Kitsap                   $3,196
# Pierce                   $2,860
# Snohomish                $2,989
# Region                   $2,669

# %% [raw]
# ### Regional Growth Center

# %%
annual_costs('is_rgc')
# Out:
#             Average Annual Costs
# is_rgc
# In RGC                      $987
# Not in RGC                $2,848
# Region                    $2,669

# %%
annual_costs('hh_rgc')
# Out:
#                                  Average Annual Costs
# hh_rgc
# Auburn                                         $1,879
# Bellevue                                       $1,045
# Bothell Canyon Park                            $2,446
# Bremerton                                      $1,246
# Burien                                         $1,823
# Everett                                        $1,133
# Federal Way                                    $1,857
# Greater Downtown Kirkland                      $2,035
# Kent                                           $1,735
# Kirkland Totem Lake                            $1,871
# Lakewood                                       $1,387
# Lynnwood                                       $1,810
# Not in RGC                                     $2,848
# Puyallup Downtown                              $1,466
# Puyallup South Hill                            $1,937
# Redmond Downtown                               $1,537
# Redmond-Overlake                               $1,411
# Renton                                         $1,546
# SeaTac                                         $2,067
# Seattle Downtown                                 $418
# Seattle First Hill/Capitol Hill                  $619
# Seattle Northgate                              $1,608
# Seattle South Lake Union                         $551
# Seattle University Community                   $1,081
# Seattle Uptown                                   $802
# Silverdale                                     $1,132
# Tacoma Downtown                                $1,027
# Tacoma Mall                                    $1,276
# Tukwila                                        $1,380
# University Place                               $1,640
# Region                                         $2,669

# %% [raw]
# ### Regional Geography

# %%
annual_costs('hh_rg_proposed')
# Out:
#                                    Average Annual Costs
# hh_rg_proposed
# Cities and Towns                                 $3,457
# Core Cities                                      $2,570
# High Capacity Transit Communities                $2,833
# Metropolitan Cities                              $1,750
# Rural Areas                                      $4,537
# Urban Unincorporated Areas                       $3,266
# Region                                           $2,669

# %% [raw]
# ### Equity Focus Areas

# %%
df = pd.DataFrame()
for name, col in {
    "People of Color": "hh_efa_poc",
    "Income": "hh_efa_pov200",
    "LEP": "hh_efa_lep",
    "Disability": "hh_efa_dis",
    "Older Adults": "hh_efa_older",
    "Youth": "hh_efa_youth"
}.items():
    _df = annual_costs(col, map=True)
    _df['Group'] = name
    df = pd.concat([df, _df])

df = df.reset_index()
df
df.rename(columns={'index':'EFA Type'}, inplace=True)

df[['Group', 'EFA Type', 'Average Annual Costs']]
# Out:
#               Group                           EFA Type  Average Annual Costs
# 0   People of Color             Below Regional Average                $2,912
# 1   People of Color             Above Regional Average                $2,380
# 2   People of Color  Higher Share of Equity Population                $2,381
# 3   People of Color                             Region                $2,669
# 4            Income             Below Regional Average                $2,892
# 5            Income             Above Regional Average                $2,470
# 6            Income  Higher Share of Equity Population                $2,095
# 7            Income                             Region                $2,669
# 8               LEP             Below Regional Average                $2,747
# 9               LEP             Above Regional Average                $2,580
# 10              LEP  Higher Share of Equity Population                $2,482
# 11              LEP                             Region                $2,669
# 12       Disability             Below Regional Average                $2,770
# 13       Disability             Above Regional Average                $2,675
# 14       Disability  Higher Share of Equity Population                $2,298
# 15       Disability                             Region                $2,669
# 16     Older Adults             Below Regional Average                $2,516
# 17     Older Adults             Above Regional Average                $2,753
# 18     Older Adults  Higher Share of Equity Population                $3,049
# 19     Older Adults                             Region                $2,669
# 20            Youth             Below Regional Average                $2,283
# 21            Youth             Above Regional Average                $3,066
# 22            Youth  Higher Share of Equity Population                $3,336
# 23            Youth                             Region                $2,669

# %% [raw]
# :::
